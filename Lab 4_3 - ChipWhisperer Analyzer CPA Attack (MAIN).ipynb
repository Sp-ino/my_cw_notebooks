# %% [markdown]
# # Part 4, Topic 3: ChipWhisperer Analyzer CPA Attack (MAIN)

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *Last time, we saw how correlation can be used to recover an AES key, as well as the effectiveness of such an attack. In this lab, we'll repeat the attack with ChipWhisperer Analyzer and gain some additional information about the attack*
#
# **LEARNING OUTCOMES:**
#
# * Use ChipWhisperer Analyzer to perform a CPA attack
# * Plot additional information about the attack

# %% [markdown]
# ## Prerequisites
#
# Hold up! Before you continue, check you've done the following tutorials:
#
# * ☑ CPA on Firmware Implementation of AES (you should understand how a CPA attack works).
# * ☑ SCA101 Intro (you should have an idea of how to get hardware-specific versions running).

# %% [markdown]
# ## Projects
#
# There's no need for any models or SBox implementaions, or anything like that this time. Instead, everything's contained in ChipWhisperer Analyzer. Another change from previous tutorials is that we're using ChipWhisperer projects instead of numpy arrays, since most of ChipWhisperer Analyzer only works with ChipWhisperer projects.
#
# As usual, see the associated notebook for details of the trace capture (or existing project) and copy below:

# %%
SCOPETYPE = 'CWNANO'
PLATFORM = 'CWNANO'
CRYPTO_TARGET='TINYAES128C' 
SS_VER='SS_VER_1_1'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Caught exception on reconnecting to target - attempting to reconnect to scope first.
# INFO: This is a work-around when USB has died without Python knowing. Ignore errors above this line.
# WARNING:ChipWhisperer NAEUSB:Your firmware is outdated - latest is 0.60. Suggested to update firmware, as you may experience errors
# See https://chipwhisperer.readthedocs.io/en/latest/api.html#firmware-update
# INFO: Found ChipWhisperer😍

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET"
# cd ../../../hardware/victims/firmware/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2
# Out:
# Building for platform CWNANO with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_1_1
# Blank crypto options, building for AES128
# rm -f -- simpleserial-aes-CWNANO.hex
# rm -f -- simpleserial-aes-CWNANO.eep
# rm -f -- simpleserial-aes-CWNANO.cof
# rm -f -- simpleserial-aes-CWNANO.elf
# rm -f -- simpleserial-aes-CWNANO.map
# rm -f -- simpleserial-aes-CWNANO.sym
# rm -f -- simpleserial-aes-CWNANO.lss
# rm -f -- objdir-CWNANO/*.o
# rm -f -- objdir-CWNANO/*.lst
# rm -f -- simpleserial-aes.s simpleserial.s stm32f0_hal_nano.s stm32f0_hal_lowlevel.s aes.s aes-independant.s
# rm -f -- simpleserial-aes.d simpleserial.d stm32f0_hal_nano.d stm32f0_hal_lowlevel.d aes.d aes-independant.d
# rm -f -- simpleserial-aes.i simpleserial.i stm32f0_hal_nano.i stm32f0_hal_lowlevel.i aes.i aes-independant.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# arm-none-eabi-gcc (Arch Repository) 11.2.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# .
# Compiling C: simpleserial-aes.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/simpleserial-aes.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/simpleserial-aes.o.d simpleserial-aes.c -o objdir-CWNANO/simpleserial-aes.o
# .
# Compiling C: .././simpleserial/simpleserial.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/simpleserial.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/simpleserial.o.d .././simpleserial/simpleserial.c -o objdir-CWNANO/simpleserial.o
# .
# Compiling C: .././hal/stm32f0_nano/stm32f0_hal_nano.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/stm32f0_hal_nano.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/stm32f0_hal_nano.o.d .././hal/stm32f0_nano/stm32f0_hal_nano.c -o objdir-CWNANO/stm32f0_hal_nano.o
# .
# Compiling C: .././hal/stm32f0/stm32f0_hal_lowlevel.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/stm32f0_hal_lowlevel.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/stm32f0_hal_lowlevel.o.d .././hal/stm32f0/stm32f0_hal_lowlevel.c -o objdir-CWNANO/stm32f0_hal_lowlevel.o
# .
# Compiling C: .././crypto/tiny-AES128-C/aes.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/aes.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/aes.o.d .././crypto/tiny-AES128-C/aes.c -o objdir-CWNANO/aes.o
# .
# Compiling C: .././crypto/aes-independant.c
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/aes-independant.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/aes-independant.o.d .././crypto/aes-independant.c -o objdir-CWNANO/aes-independant.o
# .
# Assembling: .././hal/stm32f0/stm32f0_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWNANO/stm32f0_startup.lst -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C .././hal/stm32f0/stm32f0_startup.S -o objdir-CWNANO/stm32f0_startup.o
# .
# Linking: simpleserial-aes-CWNANO.elf
# arm-none-eabi-gcc -mcpu=cortex-m0 -I. -DNO_EXTRA_OPTS -mthumb -mfloat-abi=soft -ffunction-sections -gdwarf-2 -DSS_VER=SS_VER_1_1 -DSTM32F030x6 -DSTM32F0 -DSTM32 -DDEBUG -DHAL_TYPE=HAL_stm32f0_nano -DPLATFORM=CWNANO -DTINYAES128C -DF_CPU=7372800UL -DSS_VER_2_0=2 -DSS_VER_2_1=3 -DSS_VER_1_1=1 -DSS_VER_1_0=0 -Os -funsigned-char -funsigned-bitfields -fshort-enums -Wall -Wstrict-prototypes -Wa,-adhlns=objdir-CWNANO/simpleserial-aes.o -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C -std=gnu99  -MMD -MP -MF .dep/simpleserial-aes-CWNANO.elf.d objdir-CWNANO/simpleserial-aes.o objdir-CWNANO/simpleserial.o objdir-CWNANO/stm32f0_hal_nano.o objdir-CWNANO/stm32f0_hal_lowlevel.o objdir-CWNANO/aes.o objdir-CWNANO/aes-independant.o objdir-CWNANO/stm32f0_startup.o --output simpleserial-aes-CWNANO.elf --specs=nano.specs --specs=nosys.specs -T .././hal/stm32f0_nano/LinkerScript.ld -Wl,--gc-sections -lm -mthumb -mcpu=cortex-m0  -Wl,-Map=simpleserial-aes-CWNANO.map,--cref   -lm
# .
# Creating load file for Flash: simpleserial-aes-CWNANO.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.hex
# .
# Creating load file for Flash: simpleserial-aes-CWNANO.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.bin
# .
# Creating load file for EEPROM: simpleserial-aes-CWNANO.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.eep || exit 0
# .
# Creating Extended Listing: simpleserial-aes-CWNANO.lss
# arm-none-eabi-objdump -h -S -z simpleserial-aes-CWNANO.elf > simpleserial-aes-CWNANO.lss
# .
# Creating Symbol Table: simpleserial-aes-CWNANO.sym
# arm-none-eabi-nm -n simpleserial-aes-CWNANO.elf > simpleserial-aes-CWNANO.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    5232	    540	   1628	   7400	   1ce8	simpleserial-aes-CWNANO.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CWNANO Built-in Target (STM32F030) with:
# + CRYPTO_TARGET = TINYAES128C
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "../../../hardware/victims/firmware/simpleserial-aes/simpleserial-aes-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F04xxx
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 5771 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 5771 bytes

# %% [markdown]
# Before we continue on with our CPA attack, let's take a quick look at the projects:

# %%
proj = cw.create_project("Lab 4_3", overwrite=True)

# %%
from tqdm import tnrange
import numpy as np
import time

ktp = cw.ktp.Basic()
trace_array = []
textin_array = []




N = 100
for i in tnrange(N, desc='Capturing traces'):
    key, text = ktp.next()
    trace = cw.capture_trace(scope, target, text, key)
    if not trace:
        continue
    
    proj.traces.append(trace)
# Out:
# /tmp/ipykernel_5287/3567411880.py:13: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(N, desc='Capturing traces'):
# Capturing traces:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# we can access wave, textin, etc as a whole with proj.traces
for trace in proj.traces:
    print(trace.wave[0], trace.textin, trace.textout, trace.key)

# can also access individually with proj.waves, proj.textins, etc.
for wave in proj.waves:
    print(wave[0])
# Out:
# -0.16015625 CWbytearray(b'87 cd b8 f9 5f dd 78 6c 6b 8a f1 bb d8 d4 d1 17') CWbytearray(b'6b f4 e6 55 a9 71 11 74 c3 a2 20 40 d4 74 bb 51') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'b4 58 f8 f9 bf fc 06 d6 cd c0 43 ce c5 45 69 05') CWbytearray(b'93 8b 2f 24 93 f8 6c b1 e9 28 ab 7d d2 7f f6 24') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.125 CWbytearray(b'2b 78 88 c8 af 45 d4 13 c5 22 e2 95 50 63 29 37') CWbytearray(b'89 2f 35 86 17 cc 60 29 67 5f b5 d6 20 37 79 2a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1484375 CWbytearray(b'7e 89 8a 3a 49 42 b4 aa ea 14 00 53 42 51 f0 d3') CWbytearray(b'44 db b0 4b 60 f3 b6 8c 46 1c 75 33 18 0b ae 00') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'22 96 6c 51 7c 4f 46 3f f0 6c e9 62 62 3e 28 06') CWbytearray(b'a9 87 6c 7d 3b d7 9f 16 53 63 9f f6 48 d8 ce 08') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3125 CWbytearray(b'd2 8d 8a 8e 53 71 17 a3 1d f9 47 17 9a 8f 15 c6') CWbytearray(b'01 26 58 44 52 94 1c 07 b9 a4 81 83 26 90 bd 01') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'cb 90 2c 32 f1 59 c2 9c de f2 19 7e 42 d2 14 c3') CWbytearray(b'97 db f1 01 0a 40 01 a7 a1 30 ad 9f fc 88 5d 8e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'7c ad 71 39 77 c0 bb 92 48 59 9d 71 43 66 0d fc') CWbytearray(b'a9 cb 2d fa a2 e1 23 b4 93 28 1a a7 b3 98 cc a4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'ad 0a c5 6a 47 a6 30 c1 51 cb 26 56 26 16 55 1f') CWbytearray(b'46 0e 29 78 79 e3 6e 9d eb f4 bf c3 f3 a8 1a c9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'24 ad 7a 12 6c cf 54 12 bc 29 c9 6c b9 1b ea cb') CWbytearray(b'5d eb b8 14 15 bf 7e 6d bb 32 82 0a d2 70 a1 56') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'15 f1 00 b4 57 d1 cd b5 92 9d 52 af f5 e3 cd 7c') CWbytearray(b'35 f2 1b d5 95 cf 8e e6 d8 ce 04 49 48 aa 11 81') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'b5 50 47 5a 91 2b ed f4 b9 94 91 c7 75 cd 1c 04') CWbytearray(b'f7 40 8a fd e8 da da 90 a5 3f ac 3f 81 78 30 e0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'78 8f 1a 25 06 5a 3e ea dc b6 9d b2 6a 40 c8 56') CWbytearray(b'8a b6 ff b5 c2 21 9c a2 a2 d8 64 37 ee f0 0f b7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'e7 28 dd f5 31 42 9b 38 b0 88 6e 2b 94 33 2e 72') CWbytearray(b'f8 75 21 c2 eb 62 a1 43 e9 68 bd 0c af dc 30 0f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'11 01 ef 03 a3 28 89 98 10 f9 23 04 d1 f0 0a f9') CWbytearray(b'0e 20 b6 1c 52 2f d9 c3 1c 59 9c b2 d0 a8 72 d5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'23 93 9f 41 ba 33 35 91 65 c3 97 f9 60 b2 9c 3e') CWbytearray(b'e1 ec 9d b3 3a 9d 3b d8 61 9b 5b 3a bb 31 08 55') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'af f6 bb 15 e1 bd 9d ba 5e dd b7 59 80 f8 8b fa') CWbytearray(b'a4 d2 f8 21 14 e9 af 91 ef 8c 84 03 fd 14 af e8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'8f 33 6d cd 89 e0 75 ef e0 d4 95 51 68 8c 07 90') CWbytearray(b'f1 16 be 1a 98 c6 5c a7 43 0a f2 ed d5 08 1b 49') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd0 2a 54 34 dd 86 13 df 93 56 b8 aa 0e ec ee 70') CWbytearray(b'45 ca b5 e4 1e 3a e4 99 e5 de bf b9 95 02 fc 5f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'1d a3 39 79 01 51 3d c0 ea 9c e6 b3 89 00 26 e8') CWbytearray(b'78 fe 04 0e d6 ab 3f 88 5c 83 93 fd 77 c3 19 52') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'37 c8 52 7f 64 4d 09 ec c8 38 f1 2f f8 0e 46 ed') CWbytearray(b'f4 ea 99 3c f7 2e e2 11 d5 13 ac 5a 1f 1c f2 8b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'd9 5e 0b 50 fd a2 9d ce 2e c0 fe 77 2f f7 c1 ee') CWbytearray(b'da c3 bc 0f 7a 3c 00 c1 bb 31 02 56 00 56 07 3c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'0e e1 8f 5f 4b f3 5c 65 3a f9 4a 90 a8 44 e9 91') CWbytearray(b'64 12 96 ae 4e e7 5b 85 59 d1 60 65 af b9 7e be') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1171875 CWbytearray(b'92 2f 6b 00 d8 77 4b 2a fa 83 12 78 f3 17 b8 90') CWbytearray(b'22 ed 03 8d ad 7f 44 15 f0 70 e5 4f 3b 9d 93 8b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15625 CWbytearray(b'80 25 fb 79 bb 8c 2e ae 69 c2 a2 0b c5 84 39 ae') CWbytearray(b'b9 ff eb 46 4f f1 93 f4 6c 80 f8 bd 94 1f 1a 85') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'cd fc cc 63 f5 78 cf 85 71 95 ec 1b b8 7a 92 92') CWbytearray(b'40 b9 90 e4 81 cc bb 97 31 24 e6 7a e9 14 63 ae') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'11 81 58 29 c8 bb c7 f0 b9 75 f8 b9 3a 98 93 e4') CWbytearray(b'bb ba af 56 1a c5 eb 88 43 a5 8d 17 89 25 26 44') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'68 e1 93 58 c6 1c 8f 45 59 8e bb d5 0e 3b dd 38') CWbytearray(b'10 6f 7f bc 3f 54 c6 f3 b2 ef 3b 06 cf 70 7b d5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15625 CWbytearray(b'69 d2 70 a8 42 98 73 f5 97 8f e0 2d bc ea d6 5b') CWbytearray(b'41 f1 ff 37 a2 7a 6d 6e 57 38 74 7d 5e 29 3b a6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'f9 83 03 9f 04 da 13 98 fc eb 12 f7 24 a9 66 5b') CWbytearray(b'49 64 70 61 fd 25 94 80 62 2f 08 04 04 e2 86 fe') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.02734375 CWbytearray(b'72 ba 11 19 52 87 7b 87 65 e2 54 55 cf 2f 7b 65') CWbytearray(b'5a 55 a8 b5 b0 4a 1e 56 1c 9d 1b ea 6c 7b 25 ee') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'a9 4b 9b e5 ac 98 31 da 0d 4c 83 e5 f0 ae be 05') CWbytearray(b'c0 9e 3b cc 6a 0d 3f af 5e b6 22 7a 31 02 ec 87') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'b0 37 5a 74 b4 9a 4d b7 96 8b bb 44 66 1f c4 51') CWbytearray(b'b1 8b 17 24 24 a3 4c 2e 22 24 62 7a 8c f4 74 49') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1171875 CWbytearray(b'5b da 95 46 cc 2f e3 ed 0c e1 8c 68 db ac e4 f1') CWbytearray(b'fb 81 37 f9 78 8d 12 c2 ab 47 ab 0c 60 64 a8 fe') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'd7 62 59 96 d9 7d f7 47 8a 0e cd 70 5d 5d 01 3e') CWbytearray(b'e3 ae 23 2d b4 64 48 b8 6a 96 65 d9 fe 20 6a 4a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'f1 57 2a 40 0c 69 91 f9 06 7c 66 f8 50 e8 3f f9') CWbytearray(b'd8 e2 4f 7c 6a f8 5b 6c c8 ae fb 13 67 e2 bc b7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'6f 1b 7a 7d 6a 5a f0 22 99 92 91 19 d5 f2 7f 56') CWbytearray(b'a1 45 41 1c 65 ce 51 38 33 c3 fd ab 78 38 b1 b5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'49 f0 e4 d0 c7 0f d1 cc 5d b3 c7 99 33 df 3e 66') CWbytearray(b'43 a9 7b 2f 16 81 6f 02 d0 d2 39 ef 5a 69 67 a8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'cc fb 43 5c 21 8c bf 94 08 14 bf d3 e4 ac 5d 0e') CWbytearray(b'2e c5 81 35 6c 63 95 bd a6 7f bf 9b 0f 39 e9 73') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'58 17 4c b5 d8 8e d6 d7 19 6a cd 87 8f 29 ef 8c') CWbytearray(b'bf d5 81 38 40 23 0d 58 9a dd c0 6c ff 8a 43 d0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'1d ef 5b 81 53 f9 70 a3 6a d5 53 00 60 9e 24 54') CWbytearray(b'e9 4f e9 62 a9 11 b4 26 70 04 db 2e 62 05 2a fc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'e4 23 b1 b5 cc 20 ab 0f 89 57 ee 86 34 de b4 81') CWbytearray(b'63 29 9a 59 37 86 5c bc 3d d7 d3 72 48 8d 60 12') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'9d 33 73 f6 8c d1 be 0a 4b 8e 98 10 b5 49 3a 82') CWbytearray(b'b8 32 69 a7 a1 7b f6 76 88 68 d0 7e 16 20 7d 8f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'c8 c3 81 9e fb 2e 8a e7 53 ba a4 62 c3 ed 00 d1') CWbytearray(b'5b 27 e3 c7 a6 a5 c7 32 0f 60 62 4a ff c0 68 03') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'00 87 dd d5 1b fc e7 b8 20 1f 7d c8 c0 90 cb 3e') CWbytearray(b'7d 38 c8 66 fd c5 96 c4 d8 af 29 3d 4d de 4d ef') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.17578125 CWbytearray(b'cd c3 b3 d6 90 ee 4a fd 8f 33 c6 61 b6 73 60 12') CWbytearray(b'61 58 57 6f 6f a1 30 51 c8 75 5d ad 13 93 71 d5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'67 1a b3 7c 90 5d 05 fd 46 bf 21 f6 b4 6c 44 1c') CWbytearray(b'0a 57 61 3a 8f c3 aa 4e 18 86 9e 03 ac d6 ad ed') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'79 50 03 79 f7 6a 41 36 13 45 b6 37 84 85 d7 12') CWbytearray(b'd3 7d 02 25 c3 03 75 90 20 6f d9 03 03 82 9a 64') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'57 0a e5 3f 1c 13 cd 39 37 6d ce 6d d8 6d e6 a6') CWbytearray(b'aa 79 29 79 36 be 42 af f0 8c 4c 51 4b 7a a6 fc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'8d be 92 9e 64 b9 c9 be 68 67 2f 4f 8c f3 19 12') CWbytearray(b'0f a7 f4 60 6a 47 c5 53 fc 97 19 26 19 53 c5 c8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'e2 5f 9d 0d 45 50 27 b0 2b 93 32 10 02 dc d7 3a') CWbytearray(b'06 f5 65 7d 3a 43 2e 13 7a 8a fb 28 54 07 3d 74') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'4a 78 cb 8a 55 55 89 fd c6 03 cb ec 57 c2 5f 67') CWbytearray(b'8a 0c ab 49 c5 fe 96 66 33 4c 1d a5 ed 4c e7 f4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1640625 CWbytearray(b'56 6f f2 ee 6a 24 10 d1 25 85 89 f2 09 20 b5 85') CWbytearray(b'32 83 bf da 7b a5 35 1b b9 d7 47 75 41 c3 6b 71') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.17578125 CWbytearray(b'13 07 95 2b 23 77 01 ee 8a ff 69 d7 c5 9b 32 61') CWbytearray(b'43 a4 02 44 18 48 a0 7c 7d ce 18 6d 02 25 28 0c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'5b cc ed fc 26 6d 17 81 3e 92 94 db 7a e4 98 4f') CWbytearray(b'1f b0 31 47 cb 64 ba 82 8f c6 03 3a 36 a9 a4 1c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'db ff c5 02 b0 64 a7 97 34 38 b3 e9 24 3d c4 fa') CWbytearray(b'93 b4 dd 4e 67 ca 7d b9 5d 30 60 cc 19 3f 98 61') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15625 CWbytearray(b'0a 35 af 90 53 36 b3 f6 ea 3f eb 16 14 39 42 12') CWbytearray(b'ec 5d d1 fd b6 3d df e8 45 c0 ed 8c 78 00 e5 aa') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'e7 5a 88 35 4c af 90 2e 2b 97 fc d8 2a 93 fb 90') CWbytearray(b'42 a4 e9 cb 19 17 b3 68 28 98 27 99 4b fd 5b 95') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'73 ac d0 80 46 60 e0 0b d7 5c 76 05 32 3e 74 96') CWbytearray(b'33 72 63 dc 89 52 70 55 fc 4b 08 88 ec f9 4d cf') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.328125 CWbytearray(b'11 7c 59 2f 85 6f 29 92 4f 69 3a 05 69 65 e9 e8') CWbytearray(b'a1 0f 81 1f 92 e4 4d 6d c8 26 43 60 96 d2 f6 85') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'49 4c 91 4b 9e 53 20 ab 9c 54 a2 66 b4 42 44 66') CWbytearray(b'75 7a 65 c9 59 c9 82 a4 50 1f b0 ae 7c e3 fc b4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'15 be fc a3 20 91 03 06 df 35 8d bd c0 d0 c8 00') CWbytearray(b'65 19 78 c1 1b 61 23 e4 2d 3f 94 fd 6e a6 f4 bb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'1c 61 ee 26 f9 1d 23 35 7f 14 97 52 5e 19 c3 ad') CWbytearray(b'a1 03 2e a4 c3 4b 2d b1 54 b2 34 d8 36 85 de d6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'78 c8 d2 66 39 62 ab 56 a9 7e 3b d8 c4 04 6c 7d') CWbytearray(b'f0 8a 98 3e 00 70 d4 10 ce ba 82 32 46 f5 0d 29') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'75 4d 88 66 2d d4 1f 35 c1 4f 7a f6 48 a5 40 b0') CWbytearray(b'c8 5f 17 74 93 ff 0a bb b3 2d ac 3c 0e b3 5c d2') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'b0 a7 34 bc c8 92 fb 53 24 b7 14 76 bc b5 ef 9b') CWbytearray(b'06 a0 84 fe 4d 20 77 ec c0 01 fd 5b ea 3a db 58') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1640625 CWbytearray(b'3d 17 aa eb f2 21 6b 75 76 a6 e5 57 04 5b 0c 1e') CWbytearray(b'1f cc 38 4a 98 eb bf 09 49 12 d2 e0 fa 45 a5 f7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'75 64 13 b3 38 9b 16 64 01 16 70 5a d6 9c 57 44') CWbytearray(b'9a 56 97 55 17 c5 8f ab 50 2f 0f 2c 1c 67 ae b5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'23 75 36 d0 9d 2f ba 0d e9 5e dd 34 48 f8 70 5b') CWbytearray(b'4b 91 7d c5 d2 26 d0 6a 50 c1 c4 96 66 47 60 0b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'f0 3d e7 59 b6 aa 56 eb dc 2a 3e b1 31 e3 32 68') CWbytearray(b'56 d3 5d 76 c8 8a 0d cf 34 d2 be 25 77 1d 5a cd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'4c 7a 96 33 3f 1a 0c 3a 70 d3 0e 8f df e6 fa 3a') CWbytearray(b'9b 4d 72 37 e4 3d 8e 0f 5e 80 75 fd 97 8a e6 9f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'03 16 f8 9d 16 c3 4d 0d 13 a4 fa 2a 7e 72 b7 fa') CWbytearray(b'a2 d5 e1 d8 29 5a 21 4d a9 83 78 38 69 db d4 12') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'16 27 70 89 7b 85 07 41 2b 5a ae c8 ab 99 97 e5') CWbytearray(b'23 7c 5d 60 9f 2e a2 5f 16 89 43 98 0c 66 9a 5d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'7b eb d0 fb 48 e4 2b 5d 68 22 51 4e 5c e9 2b f6') CWbytearray(b'19 db ac af 2b ea a8 ac 74 b7 a4 28 41 59 07 73') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'45 43 69 4a 66 1c e3 7a 88 0a 75 82 b7 2a 45 36') CWbytearray(b'30 83 3c f9 05 2a 47 3d 25 ea 06 e4 5e f8 46 d3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.32421875 CWbytearray(b'aa f6 f5 5d 43 08 10 62 06 d1 64 aa 81 03 99 95') CWbytearray(b'1f 1d d4 39 72 b5 5a a8 70 54 92 ee ef 8d 02 c2') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3125 CWbytearray(b'6f ef 34 e3 da d5 fd 6e 8f d3 c8 e2 68 ce 25 fa') CWbytearray(b'cf 78 4d d3 2d f2 8e 31 79 92 8a 39 0e ee 21 cf') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'03 6f 22 8b 0f 35 8e ac 44 ed 4d 3a e5 f3 80 5e') CWbytearray(b'99 1d 20 8d 1d 27 10 aa f0 c1 c3 fc f8 0f 2e ed') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.125 CWbytearray(b'd0 54 5b 7d 4d de a6 04 3f c8 be 2a 5e 35 59 14') CWbytearray(b'ea ec 16 ec 0d 30 71 44 32 75 1a 0c 93 0f bb aa') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1875 CWbytearray(b'00 e2 7d d6 6b 13 91 84 9f 14 90 df 7a 9f 8e eb') CWbytearray(b'b7 ac 23 c6 03 67 a0 95 b7 37 f3 b5 a9 c7 ef 25') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'e7 cb d8 97 0a e8 83 9c 81 bb 6d d2 93 44 40 8e') CWbytearray(b'ae 67 12 01 4a 30 44 64 95 cb 0c b5 d8 3b 96 51') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'04 92 f0 b7 8e f3 6d e2 52 e3 ac 02 b5 bd ec e7') CWbytearray(b'3a 97 21 6d bd 95 33 aa e7 c5 34 6f 5d 79 31 ca') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'c4 69 ef 00 3e 81 d2 79 67 65 0e fc 99 8c 9b 26') CWbytearray(b'd5 40 d2 c3 52 94 81 79 02 4e ad 8a 98 25 46 19') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.13671875 CWbytearray(b'ed 47 1d 03 21 b8 7c 19 44 81 eb ac 08 d8 2c c5') CWbytearray(b'92 e3 98 cf ed 82 c5 77 a8 85 4e b6 cd cc 39 30') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'f9 6b cd 47 79 b7 d7 dd bd d2 25 9f c8 d2 fb 39') CWbytearray(b'44 b2 50 e0 4b 35 15 05 fe 37 1f 76 59 67 6e 8e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'0e 16 a9 07 42 42 c2 41 ad 07 c6 56 51 39 e3 59') CWbytearray(b'db b6 87 52 17 94 f3 de 3d 38 73 17 9d e9 32 0d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'32 7c f5 a6 c7 57 93 b8 04 df 9e 93 45 b9 b6 01') CWbytearray(b'a9 c1 f1 e1 40 a9 9e c5 44 a0 c3 d7 97 41 1a 9a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'39 f9 d8 11 7c a8 2e a7 8b f5 88 2a de bd 45 50') CWbytearray(b'40 5a c2 63 23 73 31 08 39 71 20 f0 c0 b8 d0 79') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'4e 5f 7a 8f 39 06 db 17 1d 69 f8 7d b6 be 8d fe') CWbytearray(b'3b 0c 0e 2f 14 c9 5c 7b d9 34 e9 60 df 2e 83 7a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.171875 CWbytearray(b'1c c0 01 1f c8 52 1c ac 25 49 63 fe ac f9 4d 1e') CWbytearray(b'5d 29 79 c0 c6 3c b7 04 39 3b 2e ea 53 fe 90 aa') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'33 2b 2a 55 58 3b cc 28 ca 40 bb cc 16 99 ce cd') CWbytearray(b'53 81 14 ef ca 1a a1 d5 65 07 4c d1 1a 52 43 83') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'7d bf ef bb 60 db 9b ba a9 ba 99 24 86 f3 d2 be') CWbytearray(b'19 72 76 ba 72 d9 29 88 ef a8 5e 5e 95 14 c0 0b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'62 fb e8 c6 06 0b 92 02 7c 4d 21 56 11 e4 95 5e') CWbytearray(b'c5 19 fb b9 26 f7 fc 99 a5 5c c7 2a 0a e1 39 da') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15625 CWbytearray(b'2a 4d 73 e6 66 30 f5 e7 e7 6c c5 ac ee 70 17 c4') CWbytearray(b'a6 06 21 89 b4 4d e2 69 ea 0f cb 0b 8c fe 52 1d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.171875 CWbytearray(b'2c 63 7f 68 cb 09 55 e6 8c 43 ba 02 d5 ef 46 ce') CWbytearray(b'4c 28 5c ff 61 35 5c 4a cd e5 c4 0d bc 32 a3 fc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'fd 8c a2 08 91 bd de ca 8c fa d7 87 2d 44 3d 40') CWbytearray(b'6f 1b e9 ec 5a 5d 11 14 b8 14 44 cf 58 aa 22 74') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'd6 ae 8f 6b 85 3d 49 5f 52 72 5b 46 61 7c a0 33') CWbytearray(b'5e 7e 8c 50 ef b2 74 ab d9 8e c0 b1 68 cf 68 77') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'cd a2 8b 29 e3 60 e5 0e e1 aa 72 13 62 8e 66 68') CWbytearray(b'fc 6e 37 3a f0 59 9b 87 ee 21 99 b7 d8 a7 6c 5f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'23 92 5d 21 8a 79 4e d5 71 61 b2 88 0f e8 62 9e') CWbytearray(b'9a 20 c8 5c c9 8c 4d bf 7b ae 19 04 e5 82 66 68') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'6a 70 02 82 90 34 4e aa 7c 7d b1 b6 bb 8d b7 ff') CWbytearray(b'c4 04 54 eb b7 7b f2 4c d5 69 b8 3c 5f cb 54 a7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'07 c6 b1 d3 06 42 a8 29 01 c5 98 0b 43 e1 43 28') CWbytearray(b'1e 61 e7 b8 63 19 40 ff 99 2d 66 9c e0 bc 57 fd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.30859375 CWbytearray(b'8f 5c d7 8f ab 7b d4 7a 39 c0 c4 94 19 76 5b 27') CWbytearray(b'b0 fc ac 8a 80 e9 58 d9 c1 6b 22 e1 8a e0 a7 06') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'2f 38 4e 08 6d 4f d0 66 6d 6c c1 e6 e3 2d 0a a9') CWbytearray(b'6c 82 35 3d 8a c1 81 7d 33 8e 88 cb f6 5d 68 be') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'62 79 b9 70 d2 43 9a 37 20 7a 5e 8b 0f 82 92 01') CWbytearray(b'92 17 8d 9f 03 55 9f b7 c6 c2 ff 86 2a ed 3e ba') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'e6 5e f0 73 ec 8e 31 9d e2 25 8f b0 7c 30 d6 6f') CWbytearray(b'56 2d d2 2d e5 fd 94 7d 77 33 9c 62 a9 83 7a ca') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'32 85 a7 a9 33 a0 18 d3 73 90 74 74 9b 5b 12 14') CWbytearray(b'54 e2 e0 ea 11 e7 b4 53 bf c5 0a 92 d0 53 a7 9d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'a5 d8 14 b7 e7 e7 7d 00 1e 27 21 79 a6 69 6e a3') CWbytearray(b'73 23 5b 88 d6 af 4c 69 ba 75 96 7a 69 23 d0 7c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'59 23 99 fd f8 60 a6 ce b5 c3 b2 f3 36 b1 34 2d') CWbytearray(b'2a 6c 9a 7e bb 09 50 f9 1e 3f 60 5a e0 9d f6 de') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'76 d3 b7 c6 9d cf 65 9f 0f ae e9 f9 d3 ec d8 13') CWbytearray(b'7e 36 79 17 ce 46 2d d3 79 f4 6d ef b0 f3 d8 d8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'0f c8 67 9e 61 a6 14 d7 bb c3 d3 e8 70 a1 d2 57') CWbytearray(b'4b 8a 30 b6 65 3d b3 64 a6 59 d9 30 02 8d c5 e3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'01 89 e8 b9 b9 b4 e9 48 7e 93 8b dd b0 ae 5d 24') CWbytearray(b'5f 5e b3 d6 bc 4e bd cd bd e2 85 23 75 06 49 66') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'c8 e5 a5 f3 aa b1 9d b0 31 be b5 5d 48 14 b1 fb') CWbytearray(b'12 c0 a4 46 f1 e6 7c 03 7e 05 e9 75 e1 9a 00 5a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'b6 9d 18 e7 15 45 bd 9c 78 88 0d 51 29 fe d3 3d') CWbytearray(b'05 73 02 7f f8 0a e3 e8 45 29 a7 25 cf ea c5 b7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'e4 93 29 f7 59 bb 84 80 1d 52 bc 0c 76 ef 76 d5') CWbytearray(b'3d 2c af 14 d4 8e 5d eb 0b f5 bb 9e 0c d7 77 94') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'3b b1 67 5a be 4e 37 53 81 a5 29 b1 75 f6 34 58') CWbytearray(b'32 bf 70 ce 8c 78 b8 9c af 2c c9 2a 20 87 5c d4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'1d 3a f7 ac 80 e4 52 16 cb 19 9e 9d d9 17 62 67') CWbytearray(b'36 93 b3 d6 19 5a 1d 93 d2 d4 fc 6e db d2 56 ea') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'b3 2a c1 c6 97 f1 e4 e1 4c fe 2e c7 3e 74 39 66') CWbytearray(b'c9 18 05 77 d6 f5 02 e2 69 64 ce af 8d 4b ce eb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19140625 CWbytearray(b'99 09 4e 41 f6 8c 6e 7a f5 5c 79 23 ff 80 91 09') CWbytearray(b'07 61 81 1c 65 05 97 bd 57 40 c9 fc a0 8f 65 d1') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'b1 8f 7f 3b 19 b9 06 df 8e b2 53 3a e7 df 26 5d') CWbytearray(b'ce dc fd 55 fd 2b 69 cb e8 32 98 d8 b9 2d f2 a9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'c0 9f 16 36 4a ae d2 9b 9a 83 b9 b7 f3 26 fd ad') CWbytearray(b'2a 3b c1 c9 8d 8f b2 2e bd 6a 47 21 cf fc d5 d6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'23 89 d2 31 f8 c4 9d 8b f2 17 3f 16 f3 68 5d f2') CWbytearray(b'a7 06 92 81 e4 95 c9 1a 85 8a 21 96 c6 4e fb 96') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19140625 CWbytearray(b'd1 2b fd e5 d7 b6 1d 5e 92 e8 42 a8 51 08 67 60') CWbytearray(b'2b 25 3b f5 4c d3 29 b3 9d 99 aa bc 18 81 69 b5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'3e b0 6b e8 19 91 bb b2 2e 49 49 c1 a4 12 34 96') CWbytearray(b'7e ad 05 15 18 6e e6 4a 3e 0c ed 9a 4e f0 74 a5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'28 38 34 4d 26 60 04 38 f0 de 9e e5 c1 ed 54 a7') CWbytearray(b'5f 28 fb e8 fe a4 26 67 80 db 4e 84 eb 79 22 a8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'4a 57 18 21 c7 f7 b4 e5 63 c1 90 37 76 21 8b fd') CWbytearray(b'47 9f cb f6 05 33 5b c8 9a 37 7e 3a f1 7d 44 bf') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'08 c4 7b d9 0c a7 45 1f 34 f3 a8 be 6c 09 e9 53') CWbytearray(b'2e 11 77 bd 4e 79 6c 04 db a5 b1 db 35 6a bf d1') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'90 d3 f7 c5 b9 b0 19 8b c1 df 8f f2 b5 24 14 fa') CWbytearray(b'0b 84 88 af 9a c5 ba e7 06 bc 84 a7 14 5e 56 59') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'20 44 df 7c 4d b9 9f 81 36 bf 1a f5 56 29 92 84') CWbytearray(b'71 7a 09 3d d2 21 87 2f 87 bc f5 c0 25 ea 52 4b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'90 b1 20 6b fb d6 e3 07 ff b2 de 6a 11 b0 0b 77') CWbytearray(b'75 f9 d1 ff d8 60 24 5c 76 52 fb c1 61 46 16 da') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'fb 39 59 bb 7b ea 9e 38 60 97 83 99 8d 4b e6 3b') CWbytearray(b'2c 02 f6 6d af 0f dd 44 8c 2a 99 6b 2a 3e 24 fe') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'6e 2d 9d c4 8f 60 c9 b6 65 fa b4 b2 ab ae b9 2d') CWbytearray(b'a3 9b 55 4d fe 7a aa 36 ed 9c f9 ef a8 eb 54 69') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.17578125 CWbytearray(b'3d b0 05 6d ee 74 de 45 ec cb 4d 00 82 7e 78 64') CWbytearray(b'c3 46 cb 74 64 90 5a a6 56 a2 2a 55 34 7d 4b 15') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.125 CWbytearray(b'4f b2 8c db 60 4c 31 51 ac 0c 88 38 a2 a3 ad 11') CWbytearray(b'1c da c3 74 ef 15 40 a2 8c b7 58 ac 05 35 52 03') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'e0 d5 01 97 94 e7 8c 85 aa 48 a4 69 c7 f2 d5 03') CWbytearray(b'81 f3 cb 3f fa 4a c9 f0 2e f4 8c 04 9f 69 62 44') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'02 f7 af 9b 9b 9f 3b 48 05 38 7f 13 9e 0e 28 54') CWbytearray(b'9c d7 0e 50 99 da dc f3 5f 4d f5 de fe c2 ac b9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'15 a2 bf dd 4e 11 88 17 e0 45 f1 0a 5d eb e2 46') CWbytearray(b'80 cf 59 e0 72 92 5a ca db 14 b8 a7 2e 02 60 2f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'b7 20 27 c1 13 a7 2c 3b 94 4e 3c 07 f7 45 44 a4') CWbytearray(b'f9 cb 7d 69 7e 76 18 f0 ed 95 c5 92 fd 25 76 f8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1640625 CWbytearray(b'57 ef 87 60 74 c1 10 f3 3f 73 8c 9e eb 57 e9 a6') CWbytearray(b'91 2b d6 08 92 03 ee 62 55 bb 5e e6 5a f5 0f 38') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.32421875 CWbytearray(b'61 f8 1a 0c 6e 77 fd d0 76 03 9e e3 dd 86 db b0') CWbytearray(b'02 5c ee 25 e4 5c 26 a5 cd 10 0e 4d b6 ef f7 58') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'63 55 dd 82 5a 21 63 07 40 4a 05 ae d6 f6 56 32') CWbytearray(b'd8 5b 9b 12 f7 d2 db 52 b9 0d 98 4a 9d 5b 1b c0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'4d 86 80 2f c1 79 7f 59 2a fa 5a 1b ca 84 b8 c5') CWbytearray(b'61 f1 d1 c6 b6 b9 a6 6e cb d7 0a 7f b0 3c 10 e2') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'a9 62 3f 51 20 db 45 b6 14 eb 49 5b ea d2 d5 79') CWbytearray(b'46 a1 7f 7c 07 74 fb c8 8a bd 79 0e de 28 00 9c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3203125 CWbytearray(b'34 2e 79 54 26 51 43 46 ec 28 f1 fe 3e 6c a3 c1') CWbytearray(b'0e 84 52 a4 a5 43 5d c5 43 5c 3f 9d ea e6 76 97') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'29 86 f1 f9 d8 ba 75 9c 2c 6f f6 ce bf 04 05 59') CWbytearray(b'a7 cb 21 57 73 db a6 19 cf 31 82 1c 0a 2c b9 8b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.30859375 CWbytearray(b'cb b7 cc ef 89 c4 6c 71 3f d9 8d 43 ac df 85 7c') CWbytearray(b'28 c6 8c f9 79 96 b4 eb c7 76 75 78 cf 7d 80 05') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'6a b2 ab fb a0 00 08 49 06 a5 2e 74 5a 52 aa 20') CWbytearray(b'b0 db 96 0f 55 60 e6 77 d1 f0 04 06 1b f6 a7 93') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'6b 24 2d 85 60 2b 44 64 1a 8c 35 bb f8 b9 48 41') CWbytearray(b'2e f3 4c 84 c3 2e 9b 63 26 4f 17 3e ad 3d 20 42') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'22 b8 63 ca 8f 26 9f d0 68 ef ea e3 79 5f 76 b7') CWbytearray(b'52 d6 69 ea 4a 32 3c 27 f9 54 bc 27 41 fc 94 18') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'ff d4 2b 28 55 1e a0 e6 9d df 18 7e 34 d2 d3 c4') CWbytearray(b'99 97 9d c0 09 a4 b2 2a 0b ee 38 19 12 23 22 bb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'9d 9d d6 c3 ef 04 f6 99 58 5f cb e7 8d ff 6f 35') CWbytearray(b'0c 48 fd 77 2e 9a 5a d4 e3 0f e8 ad 74 43 c8 d3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'60 bd bd 5f 03 71 a8 46 57 8e fe a5 05 dc a0 42') CWbytearray(b'b0 7e fa 39 4a ec ec 0b 1b fd e8 53 c5 d9 c7 2c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'd6 dd 2b 1b 3d 0f d5 09 01 32 05 04 90 68 c8 7a') CWbytearray(b'd3 2d 63 ab 4e ae 30 b2 01 cc cd 69 54 b1 e5 cd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'e8 11 48 25 a7 d9 bf 01 ce 40 1b 53 4e a4 18 bd') CWbytearray(b'b1 a8 81 a6 8e 24 d8 9c bf 32 97 e5 de 6b d2 79') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'00 e0 d0 b5 e5 9d ae 27 24 97 bd 50 83 93 a6 5b') CWbytearray(b'2c 95 76 a0 86 50 63 17 c0 f5 e2 22 00 cc f6 c7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'eb 93 9b e4 da 84 41 b8 5f 84 0e a2 31 55 7b a6') CWbytearray(b'fb 54 6a 90 0b 1a 89 5e 5e 6e e3 c8 a7 3f c1 6b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1640625 CWbytearray(b'b8 a2 cb 57 b5 a1 1b 0a 51 67 35 72 d0 54 3e 69') CWbytearray(b'56 d4 ee 15 9d 4d 4b 62 c1 82 70 c0 21 0b 99 52') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'45 56 22 27 3d 4b 15 f4 8f 0b 4a 81 ac a9 3d 70') CWbytearray(b'9f 52 0c 11 43 4a a1 8f 98 29 c6 4b f4 29 e5 5b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'bc 7a 8d 99 fb 20 bb 54 47 bb 61 c8 57 42 b4 6c') CWbytearray(b'58 4b 56 dc 38 a6 64 91 88 f4 b7 df 7e b3 75 67') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'e4 53 79 7c bc 47 4d c3 cd 6f 03 33 cb d7 7a ce') CWbytearray(b'6d cf eb 57 04 30 10 32 30 69 6b 1a ae fd 9c 22') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.171875 CWbytearray(b'4a b6 5d dc 30 aa a5 f8 cf ca e4 11 09 89 1a c6') CWbytearray(b'9d 6f 5c cd c5 23 a9 72 90 f6 ac 3d 59 80 f0 e9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'2a 03 ac 8b 98 05 97 b7 ee 10 fa f7 75 c6 c9 2b') CWbytearray(b'9d 71 24 a8 29 b7 09 21 33 4b e4 c2 5e 24 c7 b4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'a4 c3 a7 ba 61 34 59 43 fe 4b 0f 28 db 7c fb 8e') CWbytearray(b'd0 0a 10 4e 0c 0c b4 e8 18 41 08 e6 90 1a a0 90') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'7a c9 37 c2 40 28 c0 02 ba 8f 7c 0f 40 04 56 f6') CWbytearray(b'f0 9e 08 a7 50 29 5a e6 29 ed c7 ba 9a a2 aa 70') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'37 56 15 42 1b fb f3 a9 74 42 3b 33 1a d8 0a 9c') CWbytearray(b'68 32 eb 7b 9e 44 31 1c 59 70 1a 7f 41 4a 0c 1b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'6c 49 74 15 61 0e 99 80 cd 85 f2 bf 4c 3b f5 8f') CWbytearray(b'42 54 75 20 eb e3 39 85 bb 6c 47 68 62 61 bc 27') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'0b 18 45 99 72 44 f8 61 20 75 3b 0f 86 4a c4 35') CWbytearray(b'6f 61 c3 57 98 52 fa a0 7f b6 fd f5 b6 f0 e3 26') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1640625 CWbytearray(b'b2 92 2c cc 8a 8a 96 f2 f8 48 18 2c 8b 14 ba bf') CWbytearray(b'41 83 82 03 f3 3f ea 71 5e d2 3b 94 8b a5 77 dc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'6d 34 d3 9e ca 2d 30 31 fc 4c 33 ef 34 fe c4 6e') CWbytearray(b'6a 25 bb e4 a3 7e 12 ac 10 77 20 39 42 49 a0 27') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'38 a3 5f e5 91 89 9b b1 85 96 c4 4e d2 ad f4 2c') CWbytearray(b'85 c3 95 7b 09 b0 0a b8 15 a1 fa bc a8 1f b7 49') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'dd c2 3e 5d 07 c0 7a c7 ca 34 e3 5b 83 03 f5 5b') CWbytearray(b'02 ad 2a 15 88 d0 1e 04 ee d7 0b 8f 80 af 85 89') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'c1 78 92 f7 bd 36 2c c8 ce 28 37 2d a6 77 4b ef') CWbytearray(b'a9 99 32 81 39 93 8a 57 39 fa 5b f1 bc 0c 6d 85') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'fc 16 3a 93 44 b5 7e 39 09 b6 71 53 a4 23 3c 44') CWbytearray(b'88 a0 19 f6 dd fe 50 36 64 e6 3a 17 0c 25 ac 35') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'e6 1a 52 18 c9 ec aa 39 d1 e6 a8 8a 7e 93 af 27') CWbytearray(b'20 d0 e7 80 ac 86 76 0a 9e 8c 54 f3 03 0d 6b 53') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'00 d7 64 46 ba 2a 29 33 ce 86 90 b0 74 d1 24 6f') CWbytearray(b'94 38 5d 9a 69 bd 85 91 0d 60 05 d3 d3 f9 6c b6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'6d de 93 9a 9f f2 fb 45 3e b8 5c d8 a3 fb a4 8d') CWbytearray(b'2e c0 d1 11 fe 41 80 0b ba 17 f3 66 df d6 c7 5a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'11 91 2c f7 a5 a8 d0 0e e2 a0 54 0b 6c f7 47 50') CWbytearray(b'45 14 20 44 e0 44 46 4e cf 26 b7 b3 c9 cc b3 16') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'd5 27 0c 5e 60 00 0b 5e f6 84 ce d0 b7 0e b1 68') CWbytearray(b'a5 02 bf 14 3e 35 a6 d1 0d 1f 09 1c 0f 8b 23 c7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'5f 14 98 d2 f6 a2 61 d3 23 1d 45 05 21 c2 ed 21') CWbytearray(b'a2 13 8f b1 e4 09 1d e1 d4 6e bb a8 97 f1 d8 bc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'29 51 44 68 71 94 73 5f 0e f6 6f 6e 67 dd 9d f7') CWbytearray(b'f7 49 3e 8c 52 ad d5 93 7b bd ba 15 88 c6 e7 ed') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'e6 34 80 d8 89 ae b1 14 15 5d 2d f7 84 32 83 ea') CWbytearray(b'03 13 00 3f 0a 6c 81 51 98 e9 27 b9 dc b9 3a 38') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'53 c0 99 d1 3a dc 03 a7 82 c7 cf dd 1f 62 54 cb') CWbytearray(b'aa 75 ab 12 02 f4 c2 fa e4 53 d5 91 4b fc 2a 38') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'6d a0 19 94 f4 4b c7 8d b6 79 d1 3c da a8 2a ba') CWbytearray(b'fb 63 42 1f 4b 4e 27 64 6f 88 c0 83 b5 2c b8 20') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19921875 CWbytearray(b'f0 47 77 9f 32 56 08 df e3 03 85 63 97 f6 2f 68') CWbytearray(b'ba 72 22 5e 53 54 5b 63 e0 38 07 9e d9 4b aa 27') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.171875 CWbytearray(b'47 a1 b4 d9 e6 f7 f1 d5 72 1b bc f5 a4 ff e7 a6') CWbytearray(b'9d 17 c9 0a 9b 33 fe f4 bc 52 a8 68 12 47 a2 43') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'ee 85 83 7f 72 6f 42 ab 93 ca 5f 32 74 91 e7 36') CWbytearray(b'5c 74 4a 40 b8 5b 57 08 c4 38 d4 fe 17 7c ac 2b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'20 2e 55 ad 60 9e 1a 85 38 b5 0e 99 10 80 c0 dc') CWbytearray(b'95 44 94 e5 18 28 da 32 57 f6 ef da 59 21 bb d1') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'f0 9c 9f d1 ce b7 e2 0f 0f cb 40 1f 26 c6 82 5a') CWbytearray(b'78 e7 d5 44 86 89 89 41 6b f7 d4 d5 df 7f d8 bd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'c8 c8 2d b9 fc d0 74 8c 85 9d 1b e4 1e 1d fe f2') CWbytearray(b'd6 75 07 b4 04 0f 73 b9 4d a5 c8 cd f0 9f b0 68') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'8d 4f fb 0a 74 e0 30 3d 8e 01 c0 41 66 ae 27 a9') CWbytearray(b'bf c7 86 e9 c1 58 71 05 1d 1b 41 54 a2 05 77 9a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'bb e6 e6 2f 44 4e e4 f3 4f 3d 32 4e 8a e9 4a f9') CWbytearray(b'16 db 77 5d e7 0a 00 59 e9 cf 02 95 84 c7 e5 6f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'fe 6a bc 01 cd aa 32 f3 69 f6 67 1a 25 f0 ea fc') CWbytearray(b'c5 27 44 91 86 72 46 b8 91 7c 60 f0 da 3d fe 05') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'f8 08 00 c2 1d 1b 47 55 4a 29 f6 97 56 02 1b 12') CWbytearray(b'8d f6 78 19 19 d1 e9 56 62 28 e2 0d d2 83 58 ba') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd0 05 27 b6 46 b5 6c 5b 55 d0 3d 28 c4 ff 03 1c') CWbytearray(b'c4 aa 2e c8 0d b4 8b d4 b2 42 60 a7 d9 69 cc d2') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'41 3a 1e fb aa ab 80 cd 2c 8d 92 61 5c ce 32 e0') CWbytearray(b'1c f1 8d 3c be c0 c1 6c 55 72 ed cd 94 41 15 bd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'49 cc 44 ce 75 c1 51 4e a8 2e 81 bf 41 cd 55 32') CWbytearray(b'1b c5 38 c2 2f 53 f3 91 84 f5 ae 30 12 48 0c 3b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.30859375 CWbytearray(b'0b a0 49 1a b0 c7 5d 64 e1 0d 3b 65 b9 76 97 e8') CWbytearray(b'68 c9 15 4f cf a8 cf 9e d8 09 aa 2a 8c 16 ce 05') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'11 22 41 39 e3 69 dc d4 bd b2 a5 d7 35 fc a5 2c') CWbytearray(b'c6 6c fc d0 f8 e8 db b8 32 7c 93 fa 4c 85 20 de') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'8d 1d 18 8a 80 f8 f0 5e b4 c4 4e 12 2a 5d f4 25') CWbytearray(b'c9 4d 65 b5 37 94 a1 9d db bd c8 53 aa df 8e 0f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'69 77 cb be bd db 74 92 d0 09 20 44 2f 8c 80 58') CWbytearray(b'eb 31 32 10 bd ec 44 52 94 2e c1 0d 0b 94 69 03') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'e8 ec 69 e2 39 44 91 a2 5a 28 6d 8b 12 4a f8 11') CWbytearray(b'55 e6 9f c6 1b 99 cc d3 24 b1 41 6e fd f5 ad 2d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'58 bb 66 90 8b 7e ea 5c 43 f0 8e 83 a6 2b 90 1e') CWbytearray(b'0b 92 5f 4d 1a 10 60 e4 b4 07 71 ab 01 82 81 ed') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'd5 14 bb cd da 86 f2 b6 73 91 5e b8 73 bc fb c6') CWbytearray(b'44 4a a6 81 67 ef 06 37 9b 5b 2a 18 eb a8 15 f8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'4a 97 76 2b 89 6f 6d 33 88 33 02 d4 59 57 d7 ea') CWbytearray(b'4a f2 51 66 4b 72 f6 d5 0e ad 52 bf 9e cc fc 42') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1171875 CWbytearray(b'13 50 77 8c e3 90 d0 07 67 03 de 5b c4 93 3a aa') CWbytearray(b'9e 30 45 99 9f 92 92 98 bc 4e 3e 99 74 b3 68 df') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'a4 6f 7a 33 88 74 20 fb c1 48 cf 32 31 e6 2c 7c') CWbytearray(b'29 c4 cc 9d 6f 61 9c b7 d6 f5 ea 3c 90 92 a8 59') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'96 fe e2 8c 99 fc 45 0d 9c bf 02 61 e0 a3 d9 c2') CWbytearray(b'20 4e 16 35 b3 1b b7 46 70 db 6f 83 ef 78 60 b3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'a0 8c 39 84 6d 55 17 d3 a0 dc c6 54 b9 c9 fc 46') CWbytearray(b'29 36 5b e3 f7 46 77 d9 e8 2a 6a c6 30 77 44 5e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3125 CWbytearray(b'aa 45 35 10 69 90 9d 9b e2 1f 86 6b dc d0 e7 9b') CWbytearray(b'21 95 5e e2 c5 44 5e 1b e0 25 a5 e2 ef 9f 3f a5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1328125 CWbytearray(b'bb b0 9a 39 b7 d6 38 f5 83 68 51 8f b2 d1 1e a7') CWbytearray(b'e3 de 60 3d 2e 40 5f 2a 0f 0d 01 3c c8 5c 25 ee') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'cf 4c b9 2d 94 17 ec dc c0 b2 ab 85 ef 54 3e c0') CWbytearray(b'db a5 47 e7 b5 cb 42 f0 c3 73 6a f1 42 47 db 49') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd2 29 75 e3 4e 4e 14 f6 df 80 c7 89 0e d6 5a dd') CWbytearray(b'49 e3 4c 68 53 a5 f8 83 a9 f7 58 6b 11 ae bc 98') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.171875 CWbytearray(b'12 28 3f 5a 6a 8c 3b 49 88 e7 1c d7 54 67 9b be') CWbytearray(b'e1 ee 6d e5 59 20 49 9c 81 80 4a 7e 1f 7e 26 1f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'f3 87 e1 9b 6e b2 ed 19 9b bf 5d 31 c4 b6 d0 ca') CWbytearray(b'4c 2a 98 3f a4 d8 8a 5e 7f e3 14 b4 f8 dc 6a cd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.125 CWbytearray(b'4f d0 f4 01 f1 db b0 be c1 d8 a0 46 42 90 d1 d5') CWbytearray(b'0c da 6d 6d af dd 0c 0e 4a c8 3e 0e a5 54 29 42') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'4c 6d 36 bb f3 96 c1 c6 04 da 13 bd f8 87 10 38') CWbytearray(b'16 2e a9 3b d4 20 9e 81 dc f2 d9 ff 88 f8 ed 5e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'7b 4e df 41 52 5b 9f 04 9b e8 6f e7 b7 f0 2a 5e') CWbytearray(b'1a dd fc 9b f2 97 45 f4 79 1d 75 9d dc 31 5b 85') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'e8 71 98 95 8e c1 59 93 b7 01 ce e8 99 7d 06 d8') CWbytearray(b'14 09 a9 25 8d 6c 23 e3 95 75 6a 0d ea 57 48 eb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'f2 db f3 6e fb ba a6 b5 1c 61 61 e0 0c 65 9f c6') CWbytearray(b'01 70 36 6b 77 14 42 02 3d ef af 9f be 96 2d a2') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'86 93 26 ad aa c6 f1 46 60 59 cc 55 1a 6c 22 e2') CWbytearray(b'a7 c1 fa 5d 7e e4 cc 3b cd be c5 9c 37 81 e4 d9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'2f 04 98 e2 a2 74 c6 f0 d1 a7 92 47 21 87 8d 5c') CWbytearray(b'7e 15 c8 98 0c ec 71 b3 b2 31 e5 44 43 6a c7 88') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'0a 33 87 94 3a 24 a9 5b 23 e6 30 1e a6 23 cc e9') CWbytearray(b'e1 2f 06 0e 42 ca cd 06 b9 48 1a 4e 9d c7 a1 ce') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'62 b9 3a 10 8d 4b 96 75 b7 0d 22 67 2f 02 51 44') CWbytearray(b'be 68 ac b0 9e 42 88 79 a6 e3 9c c3 4c 88 c8 8b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'0c 49 26 65 cc 8d 4e af 9d 82 ae b8 ad fc f5 51') CWbytearray(b'30 f6 7d 8f f5 76 2c b5 71 ec 6d 44 94 3a cb 0d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.11328125 CWbytearray(b'b3 de 23 6b bc fb bd e7 c9 ae d1 1b ad 5d f9 48') CWbytearray(b'f7 79 d5 c2 39 1f 9f 57 6f 44 c9 ce 91 18 c6 ea') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'90 4f 19 c3 a6 58 53 8e 5d a9 29 2d da 81 5f a6') CWbytearray(b'50 1e b2 a5 39 82 c1 1c b2 6e 5d 4b 61 99 7c 53') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'0b 0b c8 0a 1b 73 46 1c c8 78 c4 41 34 8d ea 2b') CWbytearray(b'7c 35 89 be 39 21 93 e2 cc 1e 44 9d 84 06 89 b1') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'67 77 7c dc 85 1b 1a 4e 2b 41 6c 70 83 d5 fb 8b') CWbytearray(b'7e e6 60 42 1f 45 76 e1 64 45 ba cd 2f c4 88 ab') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd3 3a 34 1b ee 75 f6 fc 46 8b d9 85 cc 52 6a c9') CWbytearray(b'9a 8f 0c 3c 71 dc 0d d4 bb 01 e2 7d f9 a9 77 81') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3125 CWbytearray(b'5e f6 33 40 2b cf f7 0b 74 20 32 b4 c8 ff e4 90') CWbytearray(b'ec 8e 3f 7a 32 58 98 62 48 f9 96 5d 6f 42 53 32') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'69 13 38 ed a4 31 e1 fc 08 b9 97 a1 ea 18 29 74') CWbytearray(b'cd b6 f3 d1 c7 c7 06 77 b3 4a 40 70 d1 dc e4 59') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'a7 01 a5 de 09 26 67 88 b8 e5 f6 9a 47 9d 5c 5a') CWbytearray(b'a5 bc 24 9b 9f 0b 9f 14 1d 39 9e 8f 83 5a f2 55') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.0390625 CWbytearray(b'cf d0 6e 78 c0 93 5d af 22 ab 48 ea 49 43 2a 98') CWbytearray(b'30 bc 57 b3 f5 3c 88 cc d4 73 2f d7 02 38 9a 5d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'35 3e b8 24 62 19 45 d4 ad be 70 3f 88 05 d3 b0') CWbytearray(b'b6 f9 90 2e 06 9d 62 97 eb 15 ba 5e 57 c2 98 aa') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'de 13 0a 20 1b 10 c9 f6 d4 15 67 69 05 90 ff 4b') CWbytearray(b'1c 9f 95 85 19 d3 85 4f f1 6a 04 b6 c9 44 dd c3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1875 CWbytearray(b'7b 28 58 42 00 45 ba ae 82 cc 90 fa d9 5e 6d e1') CWbytearray(b'9d 1a 69 f6 9b ce 18 47 55 56 2d 6c ce 8a 32 1b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# ...
# -0.03515625 CWbytearray(b'e9 42 61 39 1b 13 c1 02 61 e6 68 2a a3 5f 8b 14') CWbytearray(b'e5 79 a0 ed e1 80 44 bd a2 a2 5b 69 a3 ab 97 9b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'e8 a6 a5 07 9f 6b 70 0b 22 81 15 91 eb a1 9a 70') CWbytearray(b'27 93 4e 44 1b c2 51 28 42 03 a4 0a 6f 37 91 15') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'f3 a3 a6 4d 43 32 73 5f 06 9a c7 dd 77 9d 96 e8') CWbytearray(b'f8 01 b3 aa 42 10 24 c1 31 15 5a 6a 99 6d dc 06') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19140625 CWbytearray(b'bc 39 0d 7c 84 c4 25 7d ae 40 e9 00 bb d8 59 9e') CWbytearray(b'c0 22 a1 ef da 24 0d ba 00 03 a0 86 d4 3b d8 e5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.203125 CWbytearray(b'dc 81 5a 3d 0e 7d f6 fb b0 8d c7 5f e2 90 bf 9e') CWbytearray(b'45 49 d0 16 58 29 a2 48 f6 ec bc 83 b6 3c fb 3b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'23 4f b1 64 74 d4 8d b2 60 d2 2b 26 56 f3 17 e6') CWbytearray(b'd5 71 27 0f 68 32 df c1 30 81 2b 35 a1 0c 08 80') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'69 a5 bd c7 cd 08 fb 27 d9 d7 3f 03 59 35 50 1c') CWbytearray(b'01 84 1e 15 9d eb 8f 46 cb 06 84 2c 9c 1f d6 e0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'60 cb 57 cb 7d 44 83 bd b7 6b 00 3a 41 20 cb 24') CWbytearray(b'91 a2 3e 9d 33 1b 2f e8 24 7c 04 7f cb 10 74 d4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'14 81 ae 0a b3 4f f4 c8 91 a5 95 f9 90 69 21 03') CWbytearray(b'bf 57 69 15 7a 5d b6 6b 48 fe 23 cc 03 79 26 c7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19921875 CWbytearray(b'6f 20 78 c3 0c 8b ad ac 40 03 61 ba fe fc 89 4e') CWbytearray(b'6c 41 55 d4 ef a4 d7 b0 fb b3 d1 74 8f b9 71 8a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'de 36 fa c1 48 a5 77 11 30 e1 51 71 18 58 ec 23') CWbytearray(b'37 f8 42 a0 c1 5f 76 2a 51 6c 4d 85 91 40 40 00') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'00 ea 50 a8 a0 74 e3 7c 48 d0 2c a4 6d 09 ab fd') CWbytearray(b'd7 48 3a 1a a9 a9 75 1e e4 13 98 b0 ee 19 95 ba') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'f5 8d 1d d7 59 5c 6d 2a f9 a5 a1 a5 81 1f 58 ae') CWbytearray(b'a9 97 e3 0e 66 a8 2f ec ee a5 bd ef 6c 72 2d 4d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'fa 61 90 c6 a0 07 bc 30 24 b7 7a 59 2d d2 77 8e') CWbytearray(b'cf 63 df 77 ef 41 e6 56 a1 0c b7 90 ae 73 2b 95') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15234375 CWbytearray(b'a0 c4 9d 30 d1 f2 67 a8 3e c2 a7 a1 fc 41 4a 9e') CWbytearray(b'21 08 c0 da 09 3e 86 bc 73 bb 1b 80 dd 2f d9 25') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'0d fc ea 81 ee 88 72 d8 38 b3 e9 55 8d 17 e7 cd') CWbytearray(b'f2 d6 6b f9 d8 f5 47 2e 28 5f a8 35 2e 40 e7 ea') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.30078125 CWbytearray(b'cb e3 ee 8e 79 5f c9 7f 42 e3 e4 0e e8 60 f6 f3') CWbytearray(b'5a c3 b9 b9 b8 33 a5 ae 99 8f be e3 09 58 0e 26') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3203125 CWbytearray(b'ed ec ff ad 9e ea 5f b5 82 d2 4c de c1 b7 ca 98') CWbytearray(b'ac 29 70 fd 55 b2 56 e5 b7 b7 74 b1 3b d9 4b c0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'59 02 fc 35 c7 1e 9b bc c1 a1 29 e9 4a 52 48 c7') CWbytearray(b'd4 3d 31 7f ee c6 aa 10 3b 9e fd db a3 80 aa 7e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'c9 1e 77 ef 04 b6 97 ea 39 f4 b8 25 ef ad bd 29') CWbytearray(b'62 31 fc e2 41 3d d0 92 0a 9f 3f 88 5a 47 f0 3c') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'92 99 14 7b 54 c7 7a 9f 2d d5 52 3d 00 5c f6 43') CWbytearray(b'71 a9 92 3d 86 bd c2 46 e4 cc ba c1 37 bd 5f 67') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1484375 CWbytearray(b'1c 51 e2 69 4d 65 a3 70 c2 73 c6 8c bd fb 02 75') CWbytearray(b'e6 12 1a 50 f5 bd cd ea ac c5 cf 6e c3 62 2f 50') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'2d df a2 85 8c 01 d3 a2 18 74 18 5e d7 2b 74 74') CWbytearray(b'5e b9 f2 70 ab 1a 2d 09 c1 ee 8f eb 52 8c df 04') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.3203125 CWbytearray(b'3f 69 eb 98 11 47 66 4e 85 e4 08 a1 88 c1 db f7') CWbytearray(b'8c 80 be e0 9e 73 d1 6c 03 27 db f5 ac 87 41 41') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'8a e9 c9 52 2e 15 dd 8f c5 a9 8d ae 5d 7c c9 fa') CWbytearray(b'39 9f fd f9 1e 4c 28 94 93 80 c6 43 d5 e2 19 c0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd3 6a f6 12 58 f7 18 3e 2c 23 9c 15 5d d2 32 8e') CWbytearray(b'bd e4 c1 e9 62 c3 67 d8 51 d8 00 41 6a b8 13 b7') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1171875 CWbytearray(b'd8 fb bd d0 72 c7 42 d6 06 c7 44 7d 01 f0 b5 e8') CWbytearray(b'2f fe fb 03 02 b1 ce bd 04 d4 ca 4b 9d cf 13 a4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'ea 9f 5a 89 7c b8 88 80 83 c8 fb 3a de df c7 47') CWbytearray(b'24 e0 99 ee e7 48 3f 86 48 59 e7 09 1d f8 f7 bb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'99 7a 15 fb 41 eb 29 3b 1a 1f 9a 0f 0e 29 e1 bd') CWbytearray(b'15 d2 49 70 cf 22 a9 99 c1 27 a8 90 6b 0f 0f dd') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'ed 79 e4 14 d2 45 8c 41 f5 34 3d 87 3a 4b 56 86') CWbytearray(b'73 0d 9d 01 15 ad 3b d3 a5 aa 31 38 d3 74 9d 7b') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.125 CWbytearray(b'4a d8 ae 86 b6 1b fb 76 9a af ab fa fb 43 3d 64') CWbytearray(b'd5 1d 20 dc cf 37 8b 23 8a f4 7d 26 8b 2a 44 6d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'c6 dc 83 ee e9 03 ec a7 4d 9d a8 6c 31 60 23 10') CWbytearray(b'4a c0 38 a2 3c 49 04 21 02 a9 11 c2 10 d8 de 85') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'da 11 75 8a da 80 c4 1c 68 2a fa 2a 5f 37 11 42') CWbytearray(b'27 1f d1 52 87 35 70 01 22 61 64 3a c6 ce 69 03') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'd4 87 71 52 e3 b4 eb f4 de 71 23 c2 0a 4d 60 e7') CWbytearray(b'30 cf 13 63 14 03 a4 53 21 57 f2 c6 4c ca 9e b6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'91 3e ac 9d 30 aa 9e fd fd d3 af 2c cd 81 99 9a') CWbytearray(b'ac cf a2 ec 07 f6 ca 63 6a c2 a8 cd a4 60 55 df') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'23 39 22 c2 e0 30 b9 bb ea a8 f1 00 8e 63 f5 88') CWbytearray(b'd6 2c ce ba dc 2e 0b 9e aa b4 c7 47 d5 a8 29 6e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'ed 68 1e 1c 89 7f 5a 41 f2 c8 8b 9f c6 56 f2 cf') CWbytearray(b'45 28 69 f6 ff 14 a1 bb 3c b6 35 7e 29 2d 49 5f') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12109375 CWbytearray(b'9f 9e 40 d3 de dd 1f b4 94 9a a8 6f 76 b7 23 cd') CWbytearray(b'32 2d eb 06 17 8c 3c 3f a5 a8 95 63 8d 57 5e f9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.11328125 CWbytearray(b'dc 97 48 97 9f 66 29 3a 12 cf 6a ec 0c e2 d0 62') CWbytearray(b'61 a8 14 cf c2 48 b6 2f e3 67 cd 1f 13 f7 7e 8d') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.12890625 CWbytearray(b'37 0b 71 26 61 03 20 50 81 27 6e 61 fd c3 b9 5b') CWbytearray(b'd2 df fc 18 85 94 e0 29 92 17 cb d8 4d 5d 09 f8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.19140625 CWbytearray(b'03 9d 37 95 7e c4 90 60 e5 df b3 ef 0b a2 ef b6') CWbytearray(b'2b be ae 30 43 77 68 67 96 78 3c c5 64 b6 d8 66') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'5e 82 60 21 b2 9e a3 b1 ba 6d a0 fa a6 01 44 79') CWbytearray(b'd4 b6 d1 cf e2 34 85 ac 30 89 ae 60 a0 3a 47 eb') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.31640625 CWbytearray(b'1a 1e 75 34 76 89 17 16 e4 dd 9f 4d 26 50 26 b3') CWbytearray(b'fb f9 55 ae b3 e2 ef 2f ac 9f 90 09 48 03 02 01') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'fe a1 56 fb 1c 5a 8d 88 16 6e 52 e4 9a 5e 69 2e') CWbytearray(b'a4 bd 71 30 9a b2 11 d0 5d db 2f 9d 8c 08 c6 cc') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'c3 71 a9 43 43 ba d4 b2 5c 0d d8 e3 25 21 08 35') CWbytearray(b'92 49 eb fc c4 82 94 84 e4 24 3e 05 fd 62 9c 65') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'cd 05 21 80 52 5e 18 a7 aa 9d e7 97 7e 5d 29 af') CWbytearray(b'a5 77 d3 11 b6 2a 9e f5 94 37 21 16 ca 6d 8d c9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.1328125 CWbytearray(b'6a ae 62 c5 3e b2 c7 e2 e7 1f 7d 23 3d 3b 6a 83') CWbytearray(b'48 c1 88 65 af 8d 3a a9 4a f8 ad 9a 38 18 d8 d9') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'9a dc a2 03 11 f7 1d 67 30 60 36 02 51 15 57 d1') CWbytearray(b'f6 cc 7a f6 2f 8c f6 1f 55 e2 a9 e9 1c 29 f1 d8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.13671875 CWbytearray(b'10 75 8e 08 c4 7b 42 2f b0 ed 96 f5 75 e6 0d bf') CWbytearray(b'16 97 c9 e1 de 5d 47 74 92 03 34 79 1d 64 df f6') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'9c 4a 73 54 3f 79 3b ea e0 d0 bd 43 cb 40 39 d6') CWbytearray(b'ab 19 d0 03 20 3c 62 d5 28 4b 9b 10 5c 76 a6 a3') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.15625 CWbytearray(b'51 43 dd 8e 82 9d 39 6b dd c5 4f 16 05 fc 76 80') CWbytearray(b'2a 64 4a b8 98 40 60 53 32 28 e2 07 39 42 3d 25') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.046875 CWbytearray(b'67 6c aa 62 9e 58 ab 35 46 aa 25 e7 79 19 2a 06') CWbytearray(b'64 a8 4a 3d f7 b8 76 97 09 c5 51 c8 14 75 bf c0') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'93 c9 7d 8a 41 b5 6e eb bf a2 6e c3 d2 46 94 a4') CWbytearray(b'b7 99 60 4f 0e 3e fb 15 fd b0 ea 03 3b 54 72 d1') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.13671875 CWbytearray(b'fe 13 4d 45 e8 a7 a6 73 a9 19 f7 60 62 e9 1b 23') CWbytearray(b'74 b2 53 ef b3 42 dd 75 f6 41 ea b9 e2 8c db 29') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'05 be 5e b3 64 12 ad 2c b8 0a 01 f5 86 13 e7 33') CWbytearray(b'7b b6 50 53 f0 f0 95 bd af 78 b7 5d f7 a7 40 d4') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625 CWbytearray(b'19 e0 e1 a2 ca 76 69 40 8c e3 87 23 ac 96 59 79') CWbytearray(b'd6 25 9a 98 e7 07 9a a7 22 fc 80 5f 66 a1 46 b5') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16796875 CWbytearray(b'1e a8 0c 06 8e 61 05 93 c7 b9 4e 66 d2 0e 4e 75') CWbytearray(b'54 2f 95 83 57 4c a0 4e 38 13 cc 33 d7 27 c4 b8') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.05078125 CWbytearray(b'94 57 00 8f c3 91 8e de 5a 9c 27 05 e6 fd 6e 0a') CWbytearray(b'4b 74 0c ed ee 85 37 14 4f 19 7f 7e af 87 60 21') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.03515625 CWbytearray(b'77 bc 5c 09 ee 16 5b b0 fe 33 81 ef 84 b8 f0 3c') CWbytearray(b'67 08 05 0a 0d 86 7a 0f e1 b7 dd 33 ab ef 13 8a') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'78 8c 66 d3 67 0a 7a b8 f2 72 30 34 ee ff f4 e2') CWbytearray(b'0f 0d 32 b7 13 15 f2 b9 4a 0d 21 b1 ae d8 e0 24') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.04296875 CWbytearray(b'a0 99 1e 1e 87 40 a3 37 73 2e 6f 74 50 fe 98 8d') CWbytearray(b'40 a4 be ae 11 29 f9 40 b4 40 18 90 3e 5f 96 4e') CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')
# -0.16015625
# -0.04296875
# -0.125
# -0.1484375
# -0.15234375
# -0.3125
# -0.15234375
# -0.16015625
# -0.046875
# -0.15234375
# -0.16015625
# -0.046875
# -0.03515625
# -0.04296875
# -0.16015625
# -0.31640625
# -0.05078125
# -0.04296875
# -0.16015625
# -0.05078125
# -0.12109375
# -0.15234375
# -0.04296875
# -0.1171875
# -0.15625
# -0.046875
# -0.31640625
# -0.04296875
# -0.15625
# -0.04296875
# -0.02734375
# -0.05078125
# -0.15234375
# -0.1171875
# -0.15234375
# -0.12890625
# -0.04296875
# -0.05078125
# -0.03515625
# -0.15234375
# -0.16015625
# -0.16015625
# -0.04296875
# -0.31640625
# -0.16796875
# -0.17578125
# -0.16015625
# -0.04296875
# -0.05078125
# -0.05078125
# -0.05078125
# -0.046875
# -0.1640625
# -0.17578125
# -0.16015625
# -0.16796875
# -0.15625
# -0.04296875
# -0.15234375
# -0.328125
# -0.04296875
# -0.05078125
# -0.12890625
# -0.16796875
# -0.16796875
# -0.16796875
# -0.1640625
# -0.03515625
# -0.04296875
# -0.05078125
# -0.04296875
# -0.16015625
# -0.16015625
# -0.16796875
# -0.03515625
# -0.32421875
# -0.3125
# -0.16015625
# -0.125
# -0.1875
# -0.04296875
# -0.16796875
# -0.16015625
# -0.13671875
# -0.03515625
# -0.03515625
# -0.31640625
# -0.31640625
# -0.04296875
# -0.171875
# -0.046875
# -0.04296875
# -0.16796875
# -0.15625
# -0.171875
# -0.16796875
# -0.05078125
# -0.16015625
# -0.31640625
# -0.16015625
# -0.16015625
# -0.30859375
# -0.12109375
# -0.16796875
# -0.12890625
# -0.12109375
# -0.16796875
# -0.16015625
# -0.03515625
# -0.12890625
# -0.16015625
# -0.046875
# -0.16015625
# -0.04296875
# -0.05078125
# -0.16015625
# -0.04296875
# -0.19140625
# -0.16796875
# -0.31640625
# -0.16015625
# -0.19140625
# -0.03515625
# -0.16015625
# -0.16796875
# -0.12109375
# -0.04296875
# -0.31640625
# -0.16015625
# -0.16015625
# -0.05078125
# -0.17578125
# -0.125
# -0.15234375
# -0.16796875
# -0.16015625
# -0.03515625
# -0.1640625
# -0.32421875
# -0.31640625
# -0.046875
# -0.12109375
# -0.3203125
# -0.04296875
# -0.30859375
# -0.16015625
# -0.15234375
# -0.31640625
# -0.046875
# -0.16796875
# -0.31640625
# -0.04296875
# -0.16015625
# -0.05078125
# -0.04296875
# -0.1640625
# -0.16796875
# -0.15234375
# -0.046875
# -0.171875
# -0.046875
# -0.31640625
# -0.16796875
# -0.16796875
# -0.16015625
# -0.16796875
# -0.1640625
# -0.05078125
# -0.05078125
# -0.12109375
# -0.16796875
# -0.31640625
# -0.16796875
# -0.05078125
# -0.31640625
# -0.04296875
# -0.16796875
# -0.03515625
# -0.16796875
# -0.046875
# -0.04296875
# -0.05078125
# -0.19921875
# -0.171875
# -0.03515625
# -0.16015625
# -0.05078125
# -0.04296875
# -0.04296875
# -0.03515625
# -0.16015625
# -0.12890625
# -0.16015625
# -0.16015625
# -0.05078125
# -0.30859375
# -0.16796875
# -0.046875
# -0.16796875
# -0.12890625
# -0.04296875
# -0.03515625
# -0.04296875
# -0.1171875
# -0.04296875
# -0.046875
# -0.16015625
# -0.3125
# -0.1328125
# -0.04296875
# -0.16015625
# -0.171875
# -0.12109375
# -0.125
# -0.046875
# -0.16015625
# -0.03515625
# -0.04296875
# -0.16796875
# -0.15234375
# -0.16796875
# -0.16796875
# -0.04296875
# -0.11328125
# -0.16015625
# -0.16796875
# -0.04296875
# -0.16015625
# -0.3125
# -0.31640625
# -0.04296875
# -0.0390625
# -0.12109375
# -0.16796875
# -0.1875
# -0.05078125
# -0.31640625
# -0.12109375
# -0.16796875
# -0.03515625
# -0.04296875
# -0.15234375
# -0.19140625
# -0.203125
# -0.16015625
# -0.16796875
# -0.04296875
# -0.04296875
# -0.19921875
# -0.046875
# -0.05078125
# -0.16015625
# -0.046875
# -0.15234375
# -0.046875
# -0.30078125
# -0.3203125
# -0.16796875
# -0.16796875
# -0.05078125
# -0.1484375
# -0.16796875
# -0.3203125
# -0.16796875
# -0.16015625
# -0.1171875
# -0.04296875
# -0.16796875
# -0.16796875
# -0.125
# -0.046875
# -0.16796875
# -0.16015625
# -0.16015625
# -0.16796875
# -0.16015625
# -0.12109375
# -0.11328125
# -0.12890625
# -0.19140625
# -0.05078125
# -0.31640625
# -0.16015625
# -0.16015625
# -0.16015625
# -0.1328125
# -0.16796875
# -0.13671875
# -0.04296875
# -0.15625
# -0.046875
# -0.16015625
# -0.13671875
# -0.16796875
# -0.16015625
# -0.16796875
# -0.05078125
# -0.03515625
# -0.04296875
# -0.04296875

# %% [markdown]
# ## ChipWhisperer Analyzer
#
# We can access Analyzer via `chipwhisperer.analyzer`:

# %%
import chipwhisperer.analyzer as cwa

# %% [markdown]
# We also have to set our leakage model to be the SBox output. ChipWhisperer Analyzer includes a bunch of different leakage models which are useful in different situations. We'll look more at that in SCA201.

# %%
leak_model = cwa.leakage_models.sbox_output

# %% [markdown]
# The rest of the setup only takes 1 line:

# %%
attack = cwa.cpa(proj, leak_model)

# %% [markdown]
# If you want to see the attack settings, you can print the cpa object:

# %%
print(attack)
# Out:
# <chipwhisperer.analyzer.attacks.cpa_new.CPA object at 0x7f2dc9a8a410>
# project     = <chipwhisperer.common.api.ProjectFormat.Project object at 0x7f2dc12dc4c0>
# leak_model  = <chipwhisperer.analyzer.attacks.models.AES128_8bit.AES128_8bit object at 0x7f2dc9a8a3e0>
# algorithm   = <chipwhisperer.analyzer.attacks.cpa_algorithms.progressive.CPAProgressive object at 0x7f2dc116a4a0>
# trace_range = [0, 300]
# point_range = [0, 5000]
# subkey_list = range(0, 16)

# %% [markdown]
# Running the attack is also done in a single line:

# %%
results = attack.run()
# Out:
# /home/spino/.local/chipwhisperer/software/chipwhisperer/analyzer/attacks/cpa_algorithms/progressive.py:140: RuntimeWarning: invalid value encountered in true_divide
#   diffs[key] = sumnum / np.sqrt(sumden)

# %% [markdown]
# Let's see if we got the AES key:

# %%
print(results)
# Out:
# Subkey KGuess Correlation
#   00    0x2B    0.87420
#   01    0x7E    0.90888
#   02    0x15    0.90681
#   03    0x16    0.88634
#   04    0x28    0.89784
#   05    0xAE    0.88657
#   06    0xD2    0.90400
#   07    0xA6    0.89417
#   08    0xAB    0.87197
#   09    0xF7    0.89520
#   10    0x15    0.91672
#   11    0x88    0.88663
#   12    0x09    0.89927
#   13    0xCF    0.89926
#   14    0x4F    0.89683
#   15    0x3C    0.89016

# %% [markdown]
# We can get the full information from the attack by calling `results.find_maximums()`, which returns:
#
# ```Python
# find_maxiums() ->
#     [subkey0_data, subkey1_data, subkey2_data, ...]
#
# subkey0_data ->
#     [guess0, guess1, guess2, ...]
#
# guess0 ->
#     (key_guess, location_of_max, correlation)
# ```
#
# For example, if you want to print the correlation of the third best guess of the 4th subkey, you would run:
#
# ```python
# print(attack_results.find_maximums()[4][3][2])
# ```
#
# Note the "point location of the max" is normally not calculated/tracked, and thus returns as a 0. Using the pandas library lets us print them nicely in a DataFrame. We have to transpose the frame to get our expected orientation:

# %%
import pandas as pd
stat_data = results.find_maximums()
df = pd.DataFrame(stat_data).transpose()
print(df.head())

# %% [markdown]
# Even better, we can use the `.style` method to customize this further. This also lets us chain formatting functions. For example, we can remove the extra 0 and clean up the data. Since we know the correct key, we can even do things like printing the key in a different colour!
#
# You can do lots of formatting thanks to the pandas library! Check out https://pandas.pydata.org/pandas-docs/stable/style.html for more details.

# %%
key = proj.keys[0]
def format_stat(stat):
    return str("{:02X}<br>{:.3f}".format(stat[0], stat[2]))

def color_corr_key(row):
    global key
    ret = [""] * 16
    for i,bnum in enumerate(row):
        if bnum[0] == key[i]:
            ret[i] = "color: red"
        else:
            ret[i] = ""
    return ret

df.head().style.format(format_stat).apply(color_corr_key, axis=1)

# %% [markdown]
# You should see red numbers printed at the top of a table. Congratulations, you've now completed a successful CPA attack against AES!
#
# Next, we'll look at how we can use some of Analyzer's other features to improve the attack process, as well as better interpret the data we have.

# %% [markdown]
# ## Reporting Intervals
#
# When we ran `attack.run()`, we processed all of the traces before getting any information back. ChipWhisperer Analyzer actually uses the "online" correlation calculation that we mentioned last time, meaning we can get feedback during the attack. This can be done by creating a callback function and passing it to `attack.run()`. This function is called each time we pass the update interval (default 25, which is the second parameter for `attack.run()`).
#
# Let's use this to update our table every 10 traces. Most of this is just putting our existing code into the callback function. We also need use the `clear_output` function to clear the table, as well as `display()` to actually get it to show up:

# %%
from IPython.display import clear_output
import numpy as np
        
def stats_callback():
    results = attack.results
    results.set_known_key(key)
    stat_data = results.find_maximums()
    df = pd.DataFrame(stat_data).transpose()
    clear_output(wait=True)
    display(df.head().style.format(format_stat).apply(color_corr_key,axis=1))
    
results = attack.run(stats_callback, 10)

# %% [markdown]
# A default jupyter callback is also available - the following **three lines** are all you need to run an attack!

# %%
import chipwhisperer as cw
cb = cwa.get_jupyter_callback(attack)
results = attack.run(cb, 10)

# %% [markdown]
# Here we used a reporting interval of 10 traces. Depending on the attack and what you want to learn from it, you may want to use higher or lower values: in general reporting less often is faster, but more frequent reporting can allow you to end a long attack early. More frequent reporting also increases the resolution of some plot data (which we will look at next).

# %% [markdown]
# ## Plot Data

# %% [markdown]
# Analyzer also includes a module to create plots to help you interpret the data. These act on one subkey at a time and return some data that we can plot using bokeh (or your graphing module of choice). Let's start by grabbing the class that does all the calculations:

# %%
plot_data = cwa.analyzer_plots(results)

# %% [markdown]
# We'll start by looking at the Output Vs. Time module, which will allow us to plot correlation of our guesses in time. This is useful for finding exactly where the operations we're attacking are. Like in previous tutorials, we'll use bokeh to plot the data we get back.
#
# The method we're interested in is `get_plot_data(bnum)`, which returns in a list: `[xrange, correct_key, incorrect_key_data, incorrect_key_data]` for the position `bnum` passed to it. The method returns two sets of incorrect key data because one is for the key guesses below the correct one, and the other is for guesses above the correct one.
#
# We'll have a lot of points, so we'll plot as usual, but at the end decimate the output:

# %%
def byte_to_color(idx):
    return hv.Palette.colormaps['Category20'](idx/16.0)

import holoviews as hv
from holoviews.operation.datashader import datashade, shade, dynspread, rasterize
from holoviews.operation import decimate
import pandas as pd, numpy as np

a = []
b = []
hv.extension('bokeh')
for i in range(0, 16):
    data = plot_data.output_vs_time(i)
    a.append(np.array(data[1]))
    b.append(np.array(data[2]))
    b.append(np.array(data[3]))
    
pda = pd.DataFrame(a).transpose().rename(str, axis='columns')
pdb = pd.DataFrame(b).transpose().rename(str, axis='columns')
curve = hv.Curve(pdb['0'], "Sample").options(color='black')
for i in range(1, 16):
    curve *= hv.Curve(pdb[str(i)]).options(color='black')
    
for i in range(0, 16):
    curve *= hv.Curve(pda[str(i)]).options(color=byte_to_color(i))
decimate(curve.opts(width=900, height=600))

# %% [markdown]
# You should see some distinctive spikes in your plot. The largest of these is where the sbox lookup is actually happening (the smaller ones are typically other AES operations that move the sbox data around). We are normally talking absolute values, so you'll see negatives in there.
#
# This information can be useful in many ways. For example, you can probably see the first 16 spikes that make up the sbox lookup are a small portion of the total trace length. If we ever needed to rerun the attack, we could capture a much smaller number of samples and speed up analysis significantly!

# %% [markdown]
# ### PGE vs. Traces
#
# The next data we'll look at is a plot of partial guessing entropy (PGE) vs. the number of traces. As mentioned before, PGE is just how many spots away from the top the actual subkey is in our table of guesses. For example, if there are 7 subkey guesses that have a higher correlation than the actual subkey, the subkey has a PGE of 7.
#
# This plot is useful for seeing how many traces were needed to actually break the AES implementation. Keep in mind, however, that the resolution of the plot is determined by the reporting interval (also note that `attack_results.find_maximums()` must be called in the callback function). In our case, we have a reporting interval of 10, so we'll have a resolution of 10 traces.
#
# This method is similar to the previous plot in that it takes `bnum` as an argument and returns a list of `[xrange, PGE]`.

# %%
ret = plot_data.pge_vs_trace(0)
curve = hv.Curve((ret[0],ret[1]), "Traces Used in Calculation", "Partial Guessing Entrop of Byte")
for bnum in range(1, 16):
    ret = plot_data.pge_vs_trace(bnum)
    curve *= hv.Curve((ret[0],ret[1])).opts(color=byte_to_color(bnum))
curve.opts(width=900, height=600)

# %% [markdown]
# You should see a number of lines that start off with high values, then rapidly drop off. You may notice that we broke the AES implementation without needing to use all of our traces.
#
# Even though we may have broken the AES implementation in fewer traces, we may not want to reduce how many traces we capture. Remember that, while we know the key here, for a real attack we won't and therefore must use the correlation to determine when we've broken a key. Our next plot will help us to determine how feesible capturing fewer traces is.

# %% [markdown]
# ### Correlation vs. Traces

# %% [markdown]
# The last plot we'll take a look at is correlation vs the number of traces. Like with PGE vs. Traces, this plot's resolution is determined by the reporting interval (10 in our case). This method returns a list of `[xrange, [data_for_kguess]]`, so we'll need to plot each guess for each subkey. Like before, we'll do the plot for the correct subkey in a changing color and the rest in black.
#
# As you will see, all the subkey guesses start of with large correlations, but all of them except for the correct guess quickly drop off. If you didn't know the key, at what point would you be sure that the guess with the highest correlation was actually the correct subkey?
#
# Let's continue and plot the correlations for the right guess and the next best one:

# %%
a = []
b = []
for bnum in range(0, 16):
    data = plot_data.corr_vs_trace(bnum)
    best = [0] * len(data[1][0])
    for i in range(256):
        if i == key[bnum]:
            a.append(np.array(data[1][i]))
        else:
            if max(best) < max(data[1][i]): best = data[1][i]
    b.append(np.array(best))

pda = pd.DataFrame(a).transpose().rename(str, axis='columns')
pdb = pd.DataFrame(b).transpose().rename(str, axis='columns')
curve = hv.Curve(pdb['0'].tolist(), "Iteration Number", "Max Correlation").options(color='black')
for i in range(1,len(pdb.columns)):
    curve *= hv.Curve(pdb[str(i)]).options(color='black')
    
for i in range(len(pda.columns)):
    curve *= hv.Curve(pda[str(i)]).options(color=byte_to_color(i))
            
curve.opts(width=900, height=600)

# %% [markdown]
# ## Conclusions & Next Steps
#
# As you've seen, Analyzer makes launching a CPA attack much easier than our manual way. It also has the advantage of capturing some interesting data for us, and reporting the attack success every so often.
#
# Congratulations, you've reached the end of the main part of SCA101! If you've got a ChipWhisperer-Lite or ChipWhisperer 1200 (Pro), there's a bonus lab that will showcase using a more realisitc trigger. This is also discussed in the slides and training videos.

# %% [markdown]
# ---
# <small>NO-FUN DISCLAIMER: This material is Copyright (C) NewAE Technology Inc., 2015-2020. ChipWhisperer is a trademark of NewAE Technology Inc., claimed in all jurisdictions, and registered in at least the United States of America, European Union, and Peoples Republic of China.
#
# Tutorials derived from our open-source work must be released under the associated open-source license, and notice of the source must be *clearly displayed*. Only original copyright holders may license or authorize other distribution - while NewAE Technology Inc. holds the copyright for many tutorials, the github repository includes community contributions which we cannot license under special terms and **must** be maintained as an open-source release. Please contact us for special permissions (where possible).
#
# THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.</small>
